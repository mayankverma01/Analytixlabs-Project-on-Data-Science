# %% [markdown]
# # ____STATISTICAL TESTS-ASSIGNMENT____

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
import scipy.stats as stats
# %matplotlib inline

# %% [markdown]
# # 1  Dietstudy

# %%
Dietstudy=pd.read_csv('C:\\Users\\HP\\Desktop\\AnalytixLabs\\DATA SCIENCE\\6. Statistical Tests Case Study-2\\6. Statistical Tests Case Study-2\\dietstudy.csv')
Dietstudy.head()
# Out:
#    patid  age  gender  tg0  tg1  tg2  tg3  tg4  wgt0  wgt1  wgt2  wgt3  wgt4
# 0      1   45    Male  180  148  106  113  100   198   196   193   188   192
# 1      2   56    Male  139   94  119   75   92   237   233   232   228   225
# 2      3   50    Male  152  185   86  149  118   233   231   229   228   226
# 3      4   46  Female  112  145  136  149   82   179   181   177   174   172
# 4      5   64    Male  156  104  157   79   97   219   217   215   213   214

# %%
Dietstudy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 13 columns):
# patid     16 non-null int64
# age       16 non-null int64
# gender    16 non-null object
# tg0       16 non-null int64
# tg1       16 non-null int64
# tg2       16 non-null int64
# tg3       16 non-null int64
# tg4       16 non-null int64
# wgt0      16 non-null int64
# wgt1      16 non-null int64
# wgt2      16 non-null int64
# wgt3      16 non-null int64
# wgt4      16 non-null int64
# dtypes: int64(12), object(1)
# memory usage: 1.7+ KB

# %%
Dietstudy.describe()
# Out:
#            patid        age        tg0         tg1        tg2         tg3  \
# count  16.000000  16.000000   16.00000   16.000000   16.00000   16.000000
# mean    8.500000  54.687500  138.43750  124.562500  124.37500  118.812500
# std     4.760952   6.915863   29.04013   25.126264   21.85368   33.255012
# min     1.000000  45.000000   94.00000   93.000000   86.00000   75.000000
# 25%     4.750000  49.000000  110.75000  103.750000  112.00000   88.250000
# 50%     8.500000  54.000000  142.00000  124.000000  127.00000  116.000000
# 75%    12.250000  61.000000  157.00000  142.500000  138.50000  144.250000
# max    16.000000  64.000000  186.00000  185.000000  157.00000  195.000000
#
#               tg4        wgt0        wgt1       wgt2        wgt3        wgt4
# count   16.000000   16.000000   16.000000   16.00000   16.000000   16.000000
# mean   124.375000  198.375000  196.125000  194.12500  192.125000  190.312500
# ...

# %%
#  Test for Triglyceride
# Ho= there are no any difference in the Triglyceride levels
# H1= there are  difference in the Triglyceride levels
# here we will go for paired sample t test for 
# (a=tgo ,b=tg4)  
stats.ttest_rel(a=Dietstudy.tg0,b=Dietstudy.tg4)
# Out:
# Ttest_relResult(statistic=1.708339375326079, pvalue=0.10817790329711016)

# %%
stats.ttest_rel(a=Dietstudy.tg0,b=Dietstudy.tg1)
# Out:
# Ttest_relResult(statistic=1.708339375326079, pvalue=0.10817790329711016)

# %%
stats.ttest_rel(a=Dietstudy.tg0,b=Dietstudy.tg3)
# Out:
# Ttest_relResult(statistic=1.6460302971284584, pvalue=0.12054358887600601)

# %%
stats.ttest_rel(a=Dietstudy.tg0,b=Dietstudy.tg2)
# Out:
# Ttest_relResult(statistic=1.4652897466766746, pvalue=0.16348782284970503)

# %%
#stats.f_oneway(Dietstudy.tg0,Dietstudy.tg1,Dietstudy.tg2,Dietstudy.tg3,Dietstudy.tg4)

# %% [raw]
# From the above random sample test for Triglyceride levels
# p value is greter than the 0.05 and their are minor difference in t statistics.(we have low confidence level(significance level) for reject the Ho )
# => Ho is Accepted.
# It means Set of mesurment is has not changed in the Triglyceride levels sample.

# %%
#  Test for Weights
# Ho= there are no any difference in the Weights levels
# H1= there are  difference in the Weights levels
# here we will go for paired sample t test for 
# (a=wgto ,b=wgt4)  
stats.ttest_rel(a=Dietstudy.wgt1,b=Dietstudy.wgt1)
stats.ttest_rel(a=Dietstudy.wgt1,b=Dietstudy.wgt2)
stats.ttest_rel(a=Dietstudy.wgt1,b=Dietstudy.wgt3)
stats.ttest_rel(a=Dietstudy.wgt1,b=Dietstudy.wgt4)
# Out:
# Ttest_relResult(statistic=8.811307408130448, pvalue=2.569956610069865e-07)

# %% [raw]
# From the above random sample test for Weight
# p value is very very lower than the 0.05 (it means we have more evidence (Confidence level) for reject the Ho)
# => Ho is rejected
# It means Set of mesurment has changed in Weights Sample.

# %% [markdown]
# #  Creditpromo

# %%
Creditpromo=pd.read_csv('C:\\Users\\HP\\Desktop\\AnalytixLabs\\DATA SCIENCE\\6. Statistical Tests Case Study-2\\6. Statistical Tests Case Study-2\\creditpromo.csv')
Creditpromo.head(5)
# Out:
#      id         insert      dollars
# 0   148       Standard  2232.771979
# 1   572  New Promotion  1403.807542
# 2   973       Standard  2327.092181
# 3  1096       Standard  1280.030541
# 4  1541  New Promotion  1513.563200

# %%
Creditpromo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 3 columns):
# id         500 non-null int64
# insert     500 non-null object
# dollars    500 non-null float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 11.8+ KB

# %%
# Ho = NO increase in the Sales
# H1 = Increase in the Sales

# Here we are checking for two independent sample therefore,
# we are usint Independent Sample t Test.

Standard_dol=Creditpromo.dollars[Creditpromo['insert']=='Standard']
New_Promotion_dol=Creditpromo.dollars[Creditpromo['insert']=='New Promotion']


stats.ttest_ind(a=Standard_dol,b=New_Promotion_dol,equal_var=False) #Assume sample have unequal variance
# Out:
# Ttest_indResult(statistic=-2.260422726464996, pvalue=0.024226348191648994)

# %%
stats.ttest_ind(a=Standard_dol,b=New_Promotion_dol,equal_var=True) #Assume sample have equal variance
# Out:
# Ttest_indResult(statistic=-2.2604227264649963, pvalue=0.024225996894147814)

# %% [raw]
# From the above result
# p value is less than 0.05 (it means we have low evidence for reject Ho)
# => Ho is rejected So
# it means that,
# Yes,The promotion effective to increase the sales.

# %% [markdown]
# # Pollination.csv

# %%
Pollination=pd.read_csv('C:\\Users\\HP\\Desktop\\AnalytixLabs\\DATA SCIENCE\\6. Statistical Tests Case Study-2\\6. Statistical Tests Case Study-2\\pollination.csv')
Pollination.head(20)
# Out:
#       Group  Fruit_Wt  Seed_Yield_Plant  Seedling_length
# 0   Natural      1.85            147.70            16.86
# 1   Natural      1.86            136.86            16.77
# 2   Natural      1.83            149.97            16.35
# 3   Natural      1.89            172.33            18.26
# 4   Natural      1.80            144.46            17.90
# 5   Natural      1.88            138.30            16.95
# 6   Natural      1.89            150.58            18.15
# 7   Natural      1.79            140.99            18.86
# 8   Natural      1.85            140.57            18.39
# 9   Natural      1.84            138.33            18.58
# 10     Hand      2.58            224.26            18.18
# 11     Hand      2.74            197.50            18.07
# 12     Hand      2.58            230.34            19.07
# 13     Hand      2.62            217.05            19.00
# 14     Hand      2.68            233.84            18.00
# ...

# %%
Pollination.describe()
# Out:
#         Fruit_Wt  Seed_Yield_Plant  Seedling_length
# count  20.000000         20.000000        20.000000
# mean    2.207000        180.803500        18.148500
# std     0.378794         37.311011         0.881269
# min     1.790000        136.860000        16.350000
# 25%     1.850000        143.592500        17.787500
# 50%     2.115000        184.915000        18.220000
# 75%     2.580000        214.855000        18.887500
# max     2.740000        233.840000        19.360000

# %% [markdown]
# ## a:  Is the overall population of seed yield/plant (g) equals to 200?

# %%
# Here we are using One Samle T Test
# Ho = 200
# H1 # 200
stats.ttest_1samp(a=Pollination.Seed_Yield_Plant,popmean=200)
# Out:
# Ttest_1sampResult(statistic=-2.3009121248548645, pvalue=0.032891040921283025)

# %% [raw]
# From above result p value is less than 0.05
# => Ho is rejected (because we have more evidence for rejecting HO)
# it means The overall popukation of Seed yield/plant(g) unequal to 200

# %% [markdown]
# ## b:   Test whether the natural pollination and hand pollination under open firld conditions are equally effective or are significatly different.

# %%
# H0 = natural pollination and hand pollination under open field condition are equally effective.
# H1=  natural pollination and hand pollination under open field condition are significantly different.
# here i will use Independent Sample t test
natural_poll_Group=Pollination.Fruit_Wt[Pollination['Group']=='Natural']
Hand_poll_Group=Pollination.Fruit_Wt[Pollination['Group']=='Hand']
stats.ttest_ind(a=natural_poll_Group,b=Hand_poll_Group,equal_var=True)
# Out:
# Ttest_indResult(statistic=-17.669989614440286, pvalue=8.078362076486221e-13)

# %%
stats.ttest_ind(a=natural_poll_Group,b=Hand_poll_Group,equal_var=False)
# Out:
# Ttest_indResult(statistic=-17.669989614440286, pvalue=4.306871213074868e-09)

# %% [raw]
# From the above result,
# P value is very very lower than 0.05
# => Ho is rejected (because we have more evidence for reject the Ho (Confidence level>95%))
# it means There are significant difference between natural pollination and hand pollination under open field.

# %% [markdown]
# #  DVD Player

# %%
DVD_player=pd.read_csv('C:\\Users\\HP\\Desktop\\AnalytixLabs\\DATA SCIENCE\\6. Statistical Tests Case Study-2\\6. Statistical Tests Case Study-2\\dvdplayer.csv')
DVD_player.head(20)
# Out:
#        agegroup   dvdscore
# 0   65 and over  38.454803
# 1         55-64  17.669677
# 2   65 and over  31.704307
# 3   65 and over  25.924460
# 4      Under 25  30.450007
# 5      Under 25  35.609909
# 6   65 and over  29.677695
# 7         25-34  38.167369
# 8   65 and over  23.509700
# 9         45-54  26.051029
# 10        25-34  26.630205
# 11        25-34  30.670047
# 12     Under 25  40.469488
# 13  65 and over  27.563325
# 14        55-64  32.608214
# 15        35-44  21.823488
# 16        25-34  27.972810
# 17        45-54  33.427606
# 18  65 and over  26.728349
# 19     Under 25  30.791824

# %%
# Ho= Rating of various ages consumar are not different
# H1= Rating of various ages consumer are different
DVD_player.agegroup.value_counts()
# Out:
# 65 and over    17
# Under 25       13
# 35-44          12
# 25-34          10
# 45-54          10
# 55-64           6
# Name: agegroup, dtype: int64

# %%
A1=DVD_player.dvdscore[DVD_player['agegroup']=='65 and over']
A2=DVD_player.dvdscore[DVD_player['agegroup']=='Under 25']
A3=DVD_player.dvdscore[DVD_player['agegroup']=='35-44']
A4=DVD_player.dvdscore[DVD_player['agegroup']=='25-34']
A5=DVD_player.dvdscore[DVD_player['agegroup']=='45-54']
A6=DVD_player.dvdscore[DVD_player['agegroup']=='55-64']
# there are more than 2 group that's why i am using one way ANOVA test
stats.f_oneway(A1,A2,A3,A4,A5,A6)
# Out:
# F_onewayResult(statistic=6.992526962676514, pvalue=3.087324905679639e-05)

# %% [raw]
# From the above result P-valve is less than 0.05
# => Ho is rejected (cBecause we have more evidence for reject the null hypothesis)
# it means consumers of various ages rated te design differently.

# %% [markdown]
# # Sample Survey

# %%
survey=pd.read_csv('C:\\Users\\HP\\Desktop\\AnalytixLabs\\DATA SCIENCE\\6. Statistical Tests Case Study-2\\6. Statistical Tests Case Study-2\\sample_survey.csv')
survey.head(20)
# Out:
#     id               wrkstat        marital  childs   age  educ  paeduc  \
# 0    1     Working full time       Divorced     2.0  60.0  12.0    12.0
# 1    2     Working part-time  Never married     0.0  27.0  17.0    20.0
# 2    3     Working full time        Married     2.0  36.0  12.0    12.0
# 3    4     Working full time  Never married     0.0  21.0  13.0     NaN
# 4    5     Working full time  Never married     0.0  35.0  16.0     NaN
# 5    6     Working full time       Divorced     1.0  33.0  16.0     9.0
# 6    7     Working full time      Separated     0.0  43.0  12.0    14.0
# 7    8     Working full time  Never married     0.0  29.0  13.0    16.0
# 8    9     Working part-time        Married     2.0  39.0  18.0    16.0
# 9   10     Working full time       Divorced     0.0  45.0  15.0    16.0
# 10  11  Unemployed, laid off  Never married     0.0  29.0  12.0    12.0
# 11  12     Working full time        Married     1.0  41.0  15.0     NaN
# ...

# %%
#survey.info()

# %% [markdown]
# # a: Is there any relationship in between Labour force status with marita status?

# %%
# Ho = There are relationship between Labour force status with marital status
# H1 = There are no relationship between Labour force status with marital status

# Here i am doing comparison of two or more populations therefore, i am using
# Chi Square Test of Independence

t=pd.crosstab(survey.wrkstat,survey.marital)
t
# Out:
# marital                  Divorced  Married  Never married  Separated  Widowed
# wrkstat
# Keeping house                  25      200             35         13       55
# Other                          12       16             14          4        8
# Retired                        53      168             17          6      150
# School                          7        9             60          2        1
# Temporarily not working         9       23             11          1        2
# Unemployed, laid off           10       13             32          0        3
# Working full time             295      778            392         58       44
# Working part-time              35      138            102          9       20

# %%
stats.chi2_contingency(observed=t)
# Out:
# (729.2421426572284,
#  1.4875268409067568e-135,
#  28,
#  array([[ 51.69187279, 155.8869258 ,  76.84240283,  10.77879859,
#           32.8       ],
#         [  8.51024735,  25.66431095,  12.65088339,   1.7745583 ,
#            5.4       ],
#         [ 62.09328622, 187.25441696,  92.30459364,  12.94770318,
#           39.4       ],
#         [ 12.45017668,  37.5459364 ,  18.50777385,   2.59611307,
#            7.9       ],
#         [  7.24946996,  21.86219081,  10.77667845,   1.51166078,
#            4.6       ],
#         [  9.14063604,  27.56537102,  13.58798587,   1.90600707,
#            5.8       ],
#         [246.95477032, 744.74028269, 367.10989399,  51.495053  ,
#          156.7       ],
#         [ 47.90954064, 144.48056537,  71.21978799,   9.99010601,
#           30.4       ]]))

# %% [raw]
# Form the above result p vlaue < 0.05 and value of statistic is very high
# (this shows that there are lot diff. between two population)
# => Ho is Rejected (Because i have more evidence (or Confidence level > 95%) for Reject the Ho)
#
# it Means There are no relationship between Labour force status with marital status

# %% [markdown]
# # b: Do you thinks Aducational Qualification is somehow controlling the marital status?

# %%
# Ho= Educational Qualification is  controllng the marital status
# H1= Educational Qualification is not controlling the marital status

# Here i am comparing of two Categorical Variables(populations) therefore, i am using
# Chi Square Test of Independence
t=pd.crosstab(survey.degree,survey.marital)
t
# Out:
# marital         Divorced  Married  Never married  Separated  Widowed
# degree
# Bachelor              58      251            129         12       28
# Graduate              29      123             41          3        9
# High school          241      686            367         58      148
# Junior college        45      108             46          3        6
# LT High school        70      174             77         17       92

# %%
stats.chi2_contingency(observed=t)
# Out:
# (729.2421426572284,
#  1.4875268409067568e-135,
#  28,
#  array([[ 51.69187279, 155.8869258 ,  76.84240283,  10.77879859,
#           32.8       ],
#         [  8.51024735,  25.66431095,  12.65088339,   1.7745583 ,
#            5.4       ],
#         [ 62.09328622, 187.25441696,  92.30459364,  12.94770318,
#           39.4       ],
#         [ 12.45017668,  37.5459364 ,  18.50777385,   2.59611307,
#            7.9       ],
#         [  7.24946996,  21.86219081,  10.77667845,   1.51166078,
#            4.6       ],
#         [  9.14063604,  27.56537102,  13.58798587,   1.90600707,
#            5.8       ],
#         [246.95477032, 744.74028269, 367.10989399,  51.495053  ,
#          156.7       ],
#         [ 47.90954064, 144.48056537,  71.21978799,   9.99010601,
#           30.4       ]]))

# %% [raw]
# Form the above result p vlaue < 0.05 and value of statistic is very high
# (this shows that there  lot diff. between two population)
# => Ho is Rejected (Because i have more evidence (or Confidence level > 95%) for Reject the Ho)
#
# it Means Educational Qualification is not controlling the marital status.

# %% [markdown]
# # c:  Is happiness is drien by earningor marital status

# %%
c=survey[['happy','income','marital']]
c.head(10)
# Out:
#           happy          income        marital
# 0  Pretty happy  $25000 or more       Divorced
# 1  Pretty happy  $15000 - 19999  Never married
# 2    Very happy  $25000 or more        Married
# 3    Very happy  $15000 - 19999  Never married
# 4  Pretty happy  $25000 or more  Never married
# 5  Pretty happy  $20000 - 24999       Divorced
# 6    Very happy  $25000 or more      Separated
# 7  Pretty happy  $25000 or more  Never married
# 8    Very happy             NaN        Married
# 9  Pretty happy  $25000 or more       Divorced

# %% [raw]
# Case 1: Is happiness is driven by earnings?

# %%
# HO= Happiness is driven by earnings
# H1= Happiness is not driven by earnings

# we are using Chi-Squared test (Assessing the relationship between two categorical variable)

# %%
#  a=Happy,b= income
t1=pd.crosstab(c.happy,c.income)

t1
# Out:
# income         $1000 TO 2999  $10000 - 14999  $15000 - 19999  $20000 - 24999  \
# happy
# Not too happy              7              39              33              40
# Pretty happy              20             107             119             155
# Very happy                 5              44              26              50
#
# income         $25000 or more  $3000 TO 3999  $4000 TO 4999  $5000 TO 5999  \
# happy
# Not too happy             113              9              9              6
# Pretty happy              888             11             13             18
# Very happy                571              4             10             11
#
# income         $6000 TO 6999  $7000 TO 7999  $8000 TO 9999  LT $1000
# happy
# Not too happy             14             12              9        11
# Pretty happy              13             21             30        13
# Very happy                 6             14             19        11

# %%
stats.chi2_contingency(observed=t1)
# Out:
# (178.9505306121643,
#  1.4107677273473057e-26,
#  22,
#  array([[  3.89520355,  23.12777106,  21.66706973,  29.82265216,
#          191.35187424,   2.92140266,   3.89520355,   4.26037888,
#            4.01692866,   5.72108021,   7.06005643,   4.26037888],
#         [ 18.16041919, 107.82748892, 101.01733172, 139.04070939,
#          892.1305925 ,  13.62031439,  18.16041919,  19.86295848,
#           18.72793229,  26.67311568,  32.91575977,  19.86295848],
#         [  9.94437727,  59.04474002,  55.31559855,  76.13663845,
#          488.51753325,   7.45828295,   9.94437727,  10.87666264,
#           10.25513906,  14.60580411,  18.0241838 ,  10.87666264]]))

# %% [raw]
# From the above result :
# p value is less then 0.05 ( it we have more evidence for reject the Ho)
# =>Ho is rejected
# it means Happiness is not driven by earning

# %% [raw]
# Case 2: Is happiness is driven by marital?

# %%
# HO= Happiness is driven by marital
# H1= Happiness is not driven by marital

# we are using Chi-Squared test (Assessing the relationship between two categorical variable)

# %%
# a=Happy b=marital
t2=pd.crosstab(c.happy,c.marital)
t2
# Out:
# marital        Divorced  Married  Never married  Separated  Widowed
# happy
# Not too happy        72       71            108         30       59
# Pretty happy        278      684            426         49      137
# Very happy           93      582            120         13       83

# %%
stats.chi2_contingency(observed=t2)
# Out:
# (260.6894389418282,
#  9.3147261197964e-52,
#  8,
#  array([[ 53.6969697 , 162.06060606,  79.27272727,  11.15151515,
#           33.81818182],
#         [248.58538324, 750.24527629, 366.98609626,  51.62495544,
#          156.55828877],
#         [140.71764706, 424.69411765, 207.74117647,  29.22352941,
#           88.62352941]]))

# %% [raw]
# From the above result :
# p value is less then 0.05 ( it we have more evidence for reject the Ho)
# =>Ho is rejected
# it means Happiness is not driven by marital status.

# %% [markdown]
# ## over all happiness is neither driven by earning nor marital status.
