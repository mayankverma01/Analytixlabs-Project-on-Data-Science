# %% [markdown]
# # Data Handling

# %%
import pandas as pd
import pandas_profiling
import os
os.chdir("C:\\Users\\HP\Desktop\\AnalytixLabs\\PYTHON\\Python Class 5 files")

# %%
df=pd.read_excel("Superstore data.xlsx")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 7 columns):
# REF_NO       22 non-null object
# ORD_DTE      22 non-null object
# CUST_NAME    21 non-null object
# CATEGORY     22 non-null object
# PRODUCT      22 non-null object
# SALES        22 non-null float64
# PROFIT       20 non-null float64
# dtypes: float64(2), object(5)
# memory usage: 1.3+ KB

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (22, 7)

# %%
df.shape[0]
# Out:
# 22

# %%
df.shape[1]
# Out:
# 7

# %%
df.size
# Out:
# 154

# %%
df.columns
# Out:
# Index(['REF_NO', 'ORD_DTE', 'CUST_NAME', 'CATEGORY', 'PRODUCT', 'SALES',
#        'PROFIT'],
#       dtype='object')

# %%
df.dtypes
# Out:
# REF_NO        object
# ORD_DTE       object
# CUST_NAME     object
# CATEGORY      object
# PRODUCT       object
# SALES        float64
# PROFIT       float64
# dtype: object

# %%
df.count()
# Out:
# REF_NO       22
# ORD_DTE      22
# CUST_NAME    21
# CATEGORY     22
# PRODUCT      22
# SALES        22
# PROFIT       20
# dtype: int64

# %%
df.shape[0]
# Out:
# 22

# %%
# % of null value in eeach row
1-df.count()/df.shape[0]
# Out:
# REF_NO       0.000000
# ORD_DTE      0.000000
# CUST_NAME    0.045455
# CATEGORY     0.000000
# PRODUCT      0.000000
# SALES        0.000000
# PROFIT       0.090909
# dtype: float64

# %%
df.get_dtype_counts()
# Out:
# float64    2
# object     5
# dtype: int64

# %%
df.memory_usage()
# Out:
# Index         80
# REF_NO       176
# ORD_DTE      176
# CUST_NAME    176
# CATEGORY     176
# PRODUCT      176
# SALES        176
# PROFIT       176
# dtype: int64

# %%
df.describe()
# Out:
#              SALES       PROFIT
# count    22.000000    20.000000
# mean   4126.180364   773.409815
# std    1897.228937  1772.227602
# min    2104.550000 -3839.990400
# 25%    2751.954000   279.545850
# 50%    3884.880000   728.343000
# 75%    4643.800000  1586.971575
# max    9449.950000  4630.475500

# %% [markdown]
# ##  For Data Overview
# ### All The above stuff in one step

# %%
pandas_profiling.ProfileReport(df)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
# ...

# %%
# Structure

# %%
# create a column
#df.assign(cost=df.SALES-df.PROFIT)
df["COST"]=df.SALES-df.PROFIT

# %%
df
# Out:
#             REF_NO     ORD_DTE             CUST_NAME         CATEGORY  \
# 0   CA-2012-124891   7/31/2012           Rick Hansen       Technology
# 1   CA-2014-135909  10/14/2014             Jane Waco  Office Supplies
# 2   CA-2012-116638   1/28/2012           Joseph Holt        Furniture
# 3   CA-2014-143567   11/3/2014         Thomas Boland       Technology
# 4   CA-2011-154627  10/29/2011          Sue Ann Reed       Technology
# 5   CA-2013-159016   3/11/2013        Karen Ferguson       Technology
# 6   CA-2012-139731  10/15/2012            Joel Eaton        Furniture
# 7   CA-2011-168494  12/12/2011                   NaN        Furniture
# 8   CA-2011-160766   9/14/2011         Darrin Martin       Technology
# 9   US-2014-168116   11/5/2014        Grant Thornton       Technology
# 10  CA-2011-116904   9/23/2011          Sanjit Chand  Office Supplies
# 11  US-2012-163825   6/16/2012        Lena Creighton  Office Supplies
# ...

# %%
# Filters
#df.head()
df[2:5]
# Out:
#            REF_NO     ORD_DTE      CUST_NAME    CATEGORY      PRODUCT  \
# 2  CA-2012-116638   1/28/2012    Joseph Holt   Furniture       Tables
# 3  CA-2014-143567   11/3/2014  Thomas Boland  Technology  Accessories
# 4  CA-2011-154627  10/29/2011   Sue Ann Reed  Technology       Phones
#
#       SALES     PROFIT       COST
# 2  4297.644 -1862.3124  6159.9564
# 3  2249.910   517.4793  1732.4307
# 4  2735.952   341.9940  2393.9580

# %%
df[df.CATEGORY=="Technology"]
# Out:
#             REF_NO     ORD_DTE       CUST_NAME    CATEGORY      PRODUCT  \
# 0   CA-2012-124891   7/31/2012     Rick Hansen  Technology  Accessories
# 3   CA-2014-143567   11/3/2014   Thomas Boland  Technology  Accessories
# 4   CA-2011-154627  10/29/2011    Sue Ann Reed  Technology       Phones
# 5   CA-2013-159016   3/11/2013  Karen Ferguson  Technology       Phones
# 8   CA-2011-160766   9/14/2011   Darrin Martin  Technology     Machines
# 9   US-2014-168116   11/5/2014  Grant Thornton  Technology     Machines
# 12  US-2014-135013   7/25/2014     Harold Ryan  Technology      Copiers
# 13  CA-2012-111829   3/19/2012    Fred Hopkins  Technology      Copiers
# 14  CA-2014-129021   8/24/2014   Patrick Brill  Technology       Phones
# 15  CA-2012-114811   11/8/2012   Keith Dawkins  Technology     Machines
# 21  CA-2012-114811   11/8/2012   Keith Dawkins  Technology     Machines
#
#        SALES     PROFIT        COST
# 0   2309.650   762.1845   1547.4655
# ...

# %%
df.sort_values(["SALES","PROFIT"],ascending=[True,False])
# Out:
#             REF_NO     ORD_DTE             CUST_NAME         CATEGORY  \
# 16  CA-2013-143805   12/2/2013      Jonathan Doherty  Office Supplies
# 3   CA-2014-143567   11/3/2014         Thomas Boland       Technology
# 0   CA-2012-124891   7/31/2012           Rick Hansen       Technology
# 12  US-2014-135013   7/25/2014           Harold Ryan       Technology
# 6   CA-2012-139731  10/15/2012            Joel Eaton        Furniture
# 4   CA-2011-154627  10/29/2011          Sue Ann Reed       Technology
# 8   CA-2011-160766   9/14/2011         Darrin Martin       Technology
# 20  US-2012-163825   6/16/2012        Lena Creighton  Office Supplies
# 11  US-2012-163825   6/16/2012        Lena Creighton  Office Supplies
# 13  CA-2012-111829   3/19/2012          Fred Hopkins       Technology
# 7   CA-2011-168494  12/12/2011                   NaN        Furniture
# 5   CA-2013-159016   3/11/2013        Karen Ferguson       Technology
# ...

# %%
df[-df.duplicated()]
# Out:
#             REF_NO     ORD_DTE             CUST_NAME         CATEGORY  \
# 0   CA-2012-124891   7/31/2012           Rick Hansen       Technology
# 1   CA-2014-135909  10/14/2014             Jane Waco  Office Supplies
# 2   CA-2012-116638   1/28/2012           Joseph Holt        Furniture
# 3   CA-2014-143567   11/3/2014         Thomas Boland       Technology
# 4   CA-2011-154627  10/29/2011          Sue Ann Reed       Technology
# 5   CA-2013-159016   3/11/2013        Karen Ferguson       Technology
# 6   CA-2012-139731  10/15/2012            Joel Eaton        Furniture
# 7   CA-2011-168494  12/12/2011                   NaN        Furniture
# 8   CA-2011-160766   9/14/2011         Darrin Martin       Technology
# 9   US-2014-168116   11/5/2014        Grant Thornton       Technology
# 10  CA-2011-116904   9/23/2011          Sanjit Chand  Office Supplies
# 11  US-2012-163825   6/16/2012        Lena Creighton  Office Supplies
# ...

# %%
df.loc[(-df.CATEGORY.duplicated())|(-df.PRODUCT.duplicated()),["CATEGORY","PRODUCT"]].sort_values(["CATEGORY","PRODUCT"])
# Out:
#            CATEGORY      PRODUCT
# 6         Furniture       Chairs
# 2         Furniture       Tables
# 16  Office Supplies   Appliances
# 1   Office Supplies      Binders
# 0        Technology  Accessories
# 12       Technology      Copiers
# 8        Technology     Machines
# 4        Technology       Phones

# %%
df.loc[(df.PROFIT<0)]
# Out:
#             REF_NO     ORD_DTE       CUST_NAME    CATEGORY   PRODUCT  \
# 2   CA-2012-116638   1/28/2012     Joseph Holt   Furniture    Tables
# 6   CA-2012-139731  10/15/2012      Joel Eaton   Furniture    Chairs
# 9   US-2014-168116   11/5/2014  Grant Thornton  Technology  Machines
# 19  CA-2014-118892   8/18/2014    Tom Prescott   Furniture    Chairs
#
#        SALES     PROFIT        COST
# 2   4297.644 -1862.3124   6159.9564
# 6   2453.430  -350.4900   2803.9200
# 9   7999.980 -3839.9904  11839.9704
# 19  4416.174  -630.8820   5047.0560

# %%
df.loc[(df.CATEGORY=="Technology")]
# Out:
#             REF_NO     ORD_DTE       CUST_NAME    CATEGORY      PRODUCT  \
# 0   CA-2012-124891   7/31/2012     Rick Hansen  Technology  Accessories
# 3   CA-2014-143567   11/3/2014   Thomas Boland  Technology  Accessories
# 4   CA-2011-154627  10/29/2011    Sue Ann Reed  Technology       Phones
# 5   CA-2013-159016   3/11/2013  Karen Ferguson  Technology       Phones
# 8   CA-2011-160766   9/14/2011   Darrin Martin  Technology     Machines
# 9   US-2014-168116   11/5/2014  Grant Thornton  Technology     Machines
# 12  US-2014-135013   7/25/2014     Harold Ryan  Technology      Copiers
# 13  CA-2012-111829   3/19/2012    Fred Hopkins  Technology      Copiers
# 14  CA-2014-129021   8/24/2014   Patrick Brill  Technology       Phones
# 15  CA-2012-114811   11/8/2012   Keith Dawkins  Technology     Machines
# 21  CA-2012-114811   11/8/2012   Keith Dawkins  Technology     Machines
#
#        SALES     PROFIT        COST
# 0   2309.650   762.1845   1547.4655
# ...

# %%
df.loc[(df.CATEGORY=="Technology") & (df.PROFIT<0)]
# Out:
#            REF_NO    ORD_DTE       CUST_NAME    CATEGORY   PRODUCT    SALES  \
# 9  US-2014-168116  11/5/2014  Grant Thornton  Technology  Machines  7999.98
#
#       PROFIT        COST
# 9 -3839.9904  11839.9704

# %%
df.loc[(df.PRODUCT=="Tables")|(df.PRODUCT=="Phones")|(df.PRODUCT=="Appliances")]
# Out:
#             REF_NO     ORD_DTE         CUST_NAME         CATEGORY     PRODUCT  \
# 2   CA-2012-116638   1/28/2012       Joseph Holt        Furniture      Tables
# 4   CA-2011-154627  10/29/2011      Sue Ann Reed       Technology      Phones
# 5   CA-2013-159016   3/11/2013    Karen Ferguson       Technology      Phones
# 7   CA-2011-168494  12/12/2011               NaN        Furniture      Tables
# 14  CA-2014-129021   8/24/2014     Patrick Brill       Technology      Phones
# 16  CA-2013-143805   12/2/2013  Jonathan Doherty  Office Supplies  Appliances
#
#        SALES     PROFIT       COST
# 2   4297.644 -1862.3124  6159.9564
# 4   2735.952   341.9940  2393.9580
# 5   4158.912   363.9048  3795.0072
# 7   3610.848   135.4068  3475.4412
# 14  4367.896   327.5922  4040.3038
# 16  2104.550   694.5015  1410.0485

# %%
df.loc[-(df.PRODUCT=="Tables")]
# Out:
#             REF_NO     ORD_DTE             CUST_NAME         CATEGORY  \
# 0   CA-2012-124891   7/31/2012           Rick Hansen       Technology
# 1   CA-2014-135909  10/14/2014             Jane Waco  Office Supplies
# 3   CA-2014-143567   11/3/2014         Thomas Boland       Technology
# 4   CA-2011-154627  10/29/2011          Sue Ann Reed       Technology
# 5   CA-2013-159016   3/11/2013        Karen Ferguson       Technology
# 6   CA-2012-139731  10/15/2012            Joel Eaton        Furniture
# 8   CA-2011-160766   9/14/2011         Darrin Martin       Technology
# 9   US-2014-168116   11/5/2014        Grant Thornton       Technology
# 10  CA-2011-116904   9/23/2011          Sanjit Chand  Office Supplies
# 11  US-2012-163825   6/16/2012        Lena Creighton  Office Supplies
# 12  US-2014-135013   7/25/2014           Harold Ryan       Technology
# 13  CA-2012-111829   3/19/2012          Fred Hopkins       Technology
# ...

# %%
#df

# %%
#df.dropna()

# %%
df.dropna(axis=0,how="any")
# Out:
#             REF_NO     ORD_DTE             CUST_NAME         CATEGORY  \
# 0   CA-2012-124891   7/31/2012           Rick Hansen       Technology
# 1   CA-2014-135909  10/14/2014             Jane Waco  Office Supplies
# 2   CA-2012-116638   1/28/2012           Joseph Holt        Furniture
# 3   CA-2014-143567   11/3/2014         Thomas Boland       Technology
# 4   CA-2011-154627  10/29/2011          Sue Ann Reed       Technology
# 5   CA-2013-159016   3/11/2013        Karen Ferguson       Technology
# 6   CA-2012-139731  10/15/2012            Joel Eaton        Furniture
# 8   CA-2011-160766   9/14/2011         Darrin Martin       Technology
# 9   US-2014-168116   11/5/2014        Grant Thornton       Technology
# 10  CA-2011-116904   9/23/2011          Sanjit Chand  Office Supplies
# 12  US-2014-135013   7/25/2014           Harold Ryan       Technology
# 13  CA-2012-111829   3/19/2012          Fred Hopkins       Technology
# ...

# %%
df["COST1"]=df.COST.fillna(df.COST.mean())

# %%
#df

# %%
pd.cut(df.SALES,4,labels=["B1","B2","B3","B4"])
df["BINS"]=pd.cut(df.SALES,range(1000,10001,1000))

# %%
df[["BINS","SALES"]]
# Out:
#              BINS     SALES
# 0    (2000, 3000]  2309.650
# 1    (5000, 6000]  5083.960
# 2    (4000, 5000]  4297.644
# 3    (2000, 3000]  2249.910
# 4    (2000, 3000]  2735.952
# 5    (4000, 5000]  4158.912
# 6    (2000, 3000]  2453.430
# 7    (3000, 4000]  3610.848
# 8    (2000, 3000]  2799.960
# 9    (7000, 8000]  7999.980
# 10  (9000, 10000]  9449.950
# 11   (3000, 4000]  3050.376
# 12   (2000, 3000]  2399.960
# 13   (3000, 4000]  3149.930
# 14   (4000, 5000]  4367.896
# 15   (4000, 5000]  4643.800
# 16   (2000, 3000]  2104.550
# 17   (6000, 7000]  6354.950
# 18   (5000, 6000]  5443.960
# 19   (4000, 5000]  4416.174
# 20   (3000, 4000]  3050.376
# 21   (4000, 5000]  4643.800
